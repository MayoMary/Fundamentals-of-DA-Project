# %% [markdown]
# ## Fundamentals of Data Analytics project re Boxplot using Iris dataset.
# Mary McHale
# The project is based on using the boxplot function from the Python package matplotlib.pyplot
#
# #### Background
# Iris dataset was introduced by Ronald Fischer, a british statistician and biologist in 1936.
# Fischer developed a linear model to distingush the species from each other.
# The dataset contains sets of data for 3 varieties of the Iris flower - Sentosa, Versicolor and Virginica.
# 50 data readings were collected for these 3 varieties under the following 4 attributes - sepal width and length and petal width and length.
#
# #### History of the box plot
# The first boxplot were created in 1970 by a statistician named John Tukey using paper and pencil and became more widely known post publication in 1977.
# It displays the distribution of the data based and splits the data into quartiles whhere the data is sorted and divided into 4 equal parts.
#
# #### Box plot terminology
# Quartile : Describes 25% of the data, for example Q1 = data from 0% to 25%.
#
# Percentile : Describes the highest data point in a quartile, for example Qartile 1 corresponds to Percentile 25.
#
# Outliers : These are the data points which are the furthest away from the median than the extremes.
# The box plot displays the outliers and their values, shows if the data is symmetrical, if close together and if the data is 'skewed'. In addition, there are also:
#
#  - {1) 'Minimum' : The term to describe the lower extreme.
#  - (2) First quartile (Q1) : The term to describe the middle number between the lower number and the median.
#  - (3) Median : The term to describe the mid point value of the dataset.
#  - (4) Third Quartile (Q3) : The term to describe the middle number between the higher number and the median.
#  - (5) 'Maximum' : The term to describe the upper extreme.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Boxplot as per above image, displays a summary of the distribution of data very concisely with little space which is important when comparing different datasets. .
# The advantages of a box plot is that they can be computed quickly and use statistics which relate to actual data points.
# While the box plot is not as detailed as a histogram or density plot, the testament to it's effectivenes is that they are still being used nearly 50 years later as they have evolved with different variations and improvements.
#
# Reference : https://flowingdata.com/2011/12/06/40-years-of-boxplots/
# Reference : http://vita.had.co.nz/papers/boxplots.pdf
# Reference : https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
#
# ### Situations where box plots are used :
# The use of computers has greatly enhanced the ability of the box plot to show even more coomplex scenarios.
# It can be used for weighted data, spatial area weights and distance weights.

# %% [markdown]
# ### Importing the required libraries
# First, import the Pandas package which contain fuunctions to assist in analysing data. It is intended for "real world data analysis in Python." It is an open source data analysis/manipulation tool available in all languages.
# Command\functions start as "pd." and it reads the data file.
# Reference : https://pandas.pydata.org/pandas-docs/stable/index.html

# %%
import pandas as pd

# %% [markdown]
# ### Importing the dataset
# Source of data : Link https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
data = pd.read_csv("iris.csv")
print("This is data")
print(data)
# Out:
# This is data
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# ...

# %% [markdown]
# ### Analysis of data
# Use of Panda funuctions to analyse the data to get the mean, minimum, maximum, median and standard deviation.
# Example "Mean".
# Use of the space function to make reading the answers easier. " \n"
# The axis in the command is to show whether the data is to be analysed columnwise or rowwise.
# For this dataset it is row wise, therefore "axis=0". Columnwise would be axis=1.

# %%
print("Mean \n",data.mean(axis=0))
print("Min \n",data.min(axis=0))
print("Max \n",data.max(axis=0))
print("Median \n",data.median(axis=0))
print("Std Dev. \n",data.std(axis=0))
# Out:
# Mean
#  sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64
# Min
#  sepal_length       4.3
# sepal_width          2
# petal_length         1
# petal_width        0.1
# species         setosa
# dtype: object
# Max
#  sepal_length          7.9
# sepal_width           4.4
# petal_length          6.9
# petal_width           2.5
# species         virginica
# dtype: object
# Median
#  sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
# Std Dev.
#  sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %% [markdown]
# ### Further data analysis, to count the total number of individuals in each class\species, i.e. how many in Sestosa, Versicolor and Virginia
# use ".groupby" function to group the species into 3
# use ".count" function to total the number of individuals in the species.

# %%
data.groupby("species").count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %% [markdown]
# ### Further data analysis to replicate this then for the rest of the data.
# For 3 species: Setosa, Versicolor and Virginica and 4 attributes: Petal width and length; Sepal width and length
#
# Use of the ".describe" function to analyse the dataset

# %%
data.groupby("species").describe()
# Out:
#            petal_length                                               \
#                   count   mean       std  min  25%   50%    75%  max
# species
# setosa             50.0  1.464  0.173511  1.0  1.4  1.50  1.575  1.9
# versicolor         50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# virginica          50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9
#
#            petal_width        ...  sepal_length      sepal_width         \
#                  count   mean ...           75%  max       count   mean
# species                       ...
# setosa            50.0  0.244 ...           5.2  5.8        50.0  3.418
# versicolor        50.0  1.326 ...           6.3  7.0        50.0  2.770
# virginica         50.0  2.026 ...           6.9  7.9        50.0  2.974
#
#
#                  std  min    25%  50%    75%  max
# species
# setosa      0.381024  2.3  3.125  3.4  3.675  4.4
# versicolor  0.313798  2.0  2.525  2.8  3.000  3.4
# ...

# %% [markdown]
# ### Further analysis to get the median as not included in the describe function above.
# Median" function from the Panda package to find the median as it is not part of the ".describe" analysis

# %%
data.groupby("species").median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %% [markdown]
# ### The result of the analysis
# The values for the mean, minimum and maximum are the same for all x datasets, for example the max is 14. This is also the same for the results of the analysis for the y dataset and for exampl the mean value is 7.5.

# %% [markdown]
# ### Next step : plotting the data to see how it looks when plotted as a graph.
# Importing Matplotlib as it allows data to be charted, graphed,plotted easily with the minimum of commands. John D. Hunter was the original author.
# Matplotlib is a library in Jupyter Notebooks which plots the data.
# It is written mostly in Python but includes Numpy.
# The command\function is plt.plot for the dataset. PLOT sorts the data automatically.
# The double set of square brackets are used to access the column of data.
# Function plt.show() prints the output to the screen.
# First, need to use the command "import matplotlib.pyplot" into Jupyter Notebook
# Reference : https://matplotlib.org/

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creation of Boxplot
# Use of BoxPlot function from Pandas to create the boxplots for each of 3 Species and show the 4 attributes (sepal & petal width and length)
# Boxplot does not display the plots automatically so need to use the function ".show" from the Matploblib
# Adding the function "figsize=(12,8)" increases the size of the boxplots as the first output was hard to read
#
# Reference: https://pandas.pydata.org/pandas

# %%
data.boxplot(by='species',figsize=(14,10))
plt.show()

# %% [markdown]
# ### Analysis of results
# #### Petal length and width:
# Setosa is the vaiety with the lowest petal length and width. Virginica the species with the highest
# Overall, the box plot summary shows that petal length is larger compared to petal width.
#
# #### Sepal length and width :
# Sestosa is the variety with the lowest sepal length but Versicolor has the lowest width. Virginica is the species with the highest sepal length but Sestosa has the highest sepal width.
# Overall, the box plot summary shows that sepal length is more than sepal width.
#
# #### Results for individual species:
# For sepal analysis : Virginica has 3 outliers, 1 each for sepal length and 2 for sepal width.
# For petal analysis : Sestosa has 5 outliers - 3 for petal length and 2 for petal width.
#                    : Versicolor has 1 outlier on the lower extreme.

# %% [markdown]
# ### Scatter graphs compared as one alternative
# Scatter graphs in Python can be created using Matplotlib.
# Need to import the Iris dataset in a different format than used above for the boxplot.
# sklearn is a library from the Scikitlearn package where the dataset is stored there.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
# iris_sklearn
iris_sklearn = load_iris()

# Need to set x axis to 0, i.e.similar to row wise setting in Python3 as used above. 

x_index = 0

y_index = 1
 
# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris_sklearn.target_names[int(i)])
# Reference : https://www.scipy-lectures.org/packages/scikit-learn/auto_examples/plot_iris_scatter.html

# Use of 'figsize' command to increase the size of the plot. 
plt.figure(figsize=(10, 9))

plt.scatter(iris_sklearn.data[:, x_index], iris_sklearn.data[:, y_index], c=iris_sklearn.target)

plt.colorbar(ticks=[0, 1, 2], format=formatter)

plt.xlabel(iris_sklearn.feature_names[x_index])

plt.ylabel(iris_sklearn.feature_names[y_index])


plt.show()

# %% [markdown]
# ### Comaprision of scatterplot box plot summary
# Colour has been introduced to distinguish the 3 species from each other.
#
# A scatterplot graphs is used to see trends in the data and is interpreted from left to right.
#
# Advantage of scatterplot over boxplot  :
# All data points are visible and the outliers are easier to locate,for example species Setosa(in purple above) has an outlier towards the lower limit and Virginica(in yellow) has 3 outliers towards the upper limit.
#
# Disadvantage to boxplot :
# Where the data shows not follow a linear trend, it is difficult to dicipher relatinships between the variables.
# Boxplots displays the distribution of data depending on the values more clearly than scatter plots.
# It is also very hard to see the exact results for median, quartiles and percentiles.
#
# If more than 2 variables, then scatterplots cannot be used unlike the box plot.
# Boxplot results are more definitive.
#
# Misinterpretation of results can occur as the satterplot displays relationships, correlations which may not depending ont he sample and population sizes.
#
# Reference :https://www.dummies.com/education/math/statistics/how-to-interpret-a-scatterplot/

# %% [markdown]
# ### Histograms compared as the second alternative.
#
# A histogram is used to display the 'underlying frequency distribution (shape) of a set of continuous data.'
# This concept was first introduced by Karl Pearson
# #Reference : https://statistics.laerd.com/statistical-guides/understanding-histograms.php

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.datasets import load_iris

fig, axes = plt.subplots(nrows= 2, ncols=2)
# Assigning different colours to the 3 species, Setosa, Versicolor and Virginica with 
colors= ['blue', 'red', 'green']

for i, ax in enumerate(axes.flat):
    for label, color in zip(range(len(iris_sklearn.target_names)), colors):
        ax.hist(iris_sklearn.data[iris_sklearn.target==label, i], label= iris_sklearn.target_names[label], color=color)
        ax.set_xlabel(iris_sklearn.feature_names[i])  
        ax.legend(loc='upper right')
        
plt.figure(figsize=(20,20))        
plt.show()
# Reference : https://stackoverflow.com/questions/45721083/unable-to-plot-4-histograms-of-iris-dataset-features-using-matplotlib

# %% [markdown]
# ### Comaprision of histogram to box plot summary
# Similar to scatterplots, colour is also introduced in histograms to distinguish the 3 species from each other.
# By looking at the histograms initially, petal length and petal width for Sestosa appear to branch away from the normal distribution.
#
# #### Advantage of histogram over boxplot :
# Histogram makes interpretation of the data much easier than boxplotFor example, over all the data for sepal width follows a normal distribution.
# It is easier to identify overlap of the data distribution. In the histogram shown for sepal length, Versicolor adn Virginica species overlap.
#
# #### Disadvantage of histogram to boxplot :
# Histograms do not display outlier data and therefore misinterpretation of results can also occur as there are are known outliers from the boxplot and scatterplot.
#
# Reference :https://www.dummies.com/education/math/statistics/how-to-interpret-a-scatterplot/
